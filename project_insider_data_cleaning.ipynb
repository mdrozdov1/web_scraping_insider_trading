# %% [markdown]
# ### Project Insider Data Cleaning

# %%
import pandas as pd
import numpy as np
import time
import re

# %%
insiders = pd.read_csv('insiders.csv',header=None,names = ['transaction_date',
                                                           'transaction_type',
                                                           'company_name',
                                                           'ticker',
                                                           'name',
                                                           'position',
                                                           'shares_traded',
                                                           'avg_price',
                                                           'total_price',
                                                           'shares_owned',
                                                           'own_type'])

# %%
insiders.sample(5)
# Out:
#     transaction_date transaction_type                   company_name ticker  \
# 198       2014-07-07             Sale  INTERCEPT PHARMACEUTICALS INC   ICPT
# 34        2017-10-02             Sale  INTERCEPT PHARMACEUTICALS INC   ICPT
# 43        2017-07-11             Sale  INTERCEPT PHARMACEUTICALS INC   ICPT
# 13        2019-01-01             Sale  INTERCEPT PHARMACEUTICALS Inc   ICPT
# 196       2014-08-01             Sale  INTERCEPT PHARMACEUTICALS INC   ICPT
#
#                   name                   position  shares_traded  avg_price  \
# 198  TALLARIGO LORENZO                   Director           2000     243.10
# 34       McMinn Rachel     Chief Strategy Officer            283      58.89
# 43       Shapiro David  CMO and EVP - Development            553     124.00
# 13       Shapiro David      Chief Medical Officer           2699      98.07
# 196     Pruzanski Mark                        CEO          10000     226.70
#
#      total_price  shares_owned own_type
# ...
