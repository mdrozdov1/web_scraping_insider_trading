# %% [markdown]
# ### Project Insider Data Cleaning

# %%
import pandas as pd
from pandas_datareader import data
import numpy as np
from datetime import datetime
from datetime import timedelta
import re

# %%
columns = ['transaction_date', 'transaction_type', 'company_name',
           'ticker', 'name', 'position', 'shares_traded', 'avg_price',
           'total_price', 'shares_owned', 'own_type']

# %% [markdown]
# #### Insiders Data for ICPT

# %%
icpt_insiders = pd.read_csv('insiders.csv',header=None,names = columns)
icpt_insiders.index = pd.to_datetime(icpt_insiders.transaction_date)
icpt_insiders = icpt_insiders.drop('transaction_date',axis=1)
icpt_insiders = icpt_insiders[:-1]

# %%
icpt_insiders
# Out:
#                  transaction_type                   company_name ticker  \
# transaction_date
# 2019-07-01                   Sale  INTERCEPT PHARMACEUTICALS Inc   ICPT
# 2019-05-14               Purchase  INTERCEPT PHARMACEUTICALS Inc   ICPT
# 2019-05-01                   Sale  INTERCEPT PHARMACEUTICALS Inc   ICPT
# 2019-04-15                   Sale  INTERCEPT PHARMACEUTICALS Inc   ICPT
# 2019-04-01                   Sale  INTERCEPT PHARMACEUTICALS Inc   ICPT
# 2019-04-01                   Sale  INTERCEPT PHARMACEUTICALS Inc   ICPT
# 2019-03-29                   Sale  INTERCEPT PHARMACEUTICALS Inc   ICPT
# 2019-03-01                   Sale  INTERCEPT PHARMACEUTICALS Inc   ICPT
# 2019-02-27                   Sale  INTERCEPT PHARMACEUTICALS Inc   ICPT
# 2019-02-19                   Sale  INTERCEPT PHARMACEUTICALS Inc   ICPT
# 2019-02-15                   Sale  INTERCEPT PHARMACEUTICALS Inc   ICPT
# 2019-01-07                   Sale  INTERCEPT PHARMACEUTICALS Inc   ICPT
# ...

# %%
icpt_insiders[['shares_traded']].set_index(icpt_insiders.index-timedelta(days=7)).resample('W').sum()
# Out:
#                   shares_traded
# transaction_date
# 2012-10-14              1033334
# 2012-10-21                    0
# 2012-10-28                    0
# 2012-11-04                    0
# 2012-11-11                    0
# 2012-11-18                    0
# 2012-11-25                    0
# 2012-12-02                    0
# 2012-12-09                    0
# 2012-12-16                    0
# 2012-12-23                    0
# 2012-12-30                    0
# 2013-01-06                    0
# 2013-01-13                    0
# 2013-01-20                    0
# 2013-01-27                    0
# 2013-02-03                    0
# 2013-02-10                    0
# 2013-02-17                    0
# 2013-02-24                    0
# 2013-03-03                    0
# 2013-03-10                    0
# 2013-03-17                    0
# 2013-03-24                    0
# 2013-03-31                    0
# 2013-04-07                 3750
# 2013-04-14                    0
# ...

# %% [markdown]
# #### Daily Price Data for ICPT

# %%
ticker = list(set(insiders.ticker))[0]
start_date = '2012-08-09'
end_date = '2019-07-01'

# %%
icpt_data = data.DataReader(ticker,'yahoo',start_date,end_date)

# %%
icpt_data['Return'] = icpt_data['Adj Close'].diff()

# %%
icpt_data.tail()
# Out:
#                  High        Low       Open      Close  Volume  Adj Close  \
# Date
# 2019-06-26  79.400002  77.519997  78.610001  77.769997  345300  77.769997
# 2019-06-27  79.629997  78.220001  78.389999  79.410004  349200  79.410004
# 2019-06-28  80.790001  78.769997  79.379997  79.570000  833900  79.570000
# 2019-07-01  80.570000  78.099998  80.300003  79.169998  467700  79.169998
# 2019-07-02  79.709999  78.169998  78.720001  78.660004  306100  78.660004
#
#               Return
# Date
# 2019-06-26 -0.590004
# 2019-06-27  1.640007
# 2019-06-28  0.159996
# 2019-07-01 -0.400002
# 2019-07-02 -0.509995

# %%
dates1 = sorted(icpt_insiders.index)

weeks = [dates1[0]]

for i in range(len(dates1)-1):
    if dates1[i+1] > dates1[i]+timedelta(days=7):
        weeks.append(dates1[i+1])
    else:
        weeks.append(dates1[i])
        

set(weeks)
# Out:
# {Timestamp('2012-10-16 00:00:00'),
#  Timestamp('2013-04-09 00:00:00'),
#  Timestamp('2013-05-15 00:00:00'),
#  Timestamp('2013-05-20 00:00:00'),
#  Timestamp('2013-06-17 00:00:00'),
#  Timestamp('2013-06-19 00:00:00'),
#  Timestamp('2013-06-20 00:00:00'),
#  Timestamp('2013-06-25 00:00:00'),
#  Timestamp('2013-07-01 00:00:00'),
#  Timestamp('2013-07-08 00:00:00'),
#  Timestamp('2013-07-22 00:00:00'),
#  Timestamp('2013-08-09 00:00:00'),
#  Timestamp('2013-08-12 00:00:00'),
#  Timestamp('2013-08-15 00:00:00'),
#  Timestamp('2013-09-05 00:00:00'),
#  Timestamp('2013-09-12 00:00:00'),
#  Timestamp('2013-09-16 00:00:00'),
#  Timestamp('2013-09-17 00:00:00'),
#  Timestamp('2013-10-01 00:00:00'),
#  Timestamp('2013-10-15 00:00:00'),
#  Timestamp('2013-10-21 00:00:00'),
#  Timestamp('2013-11-09 00:00:00'),
#  Timestamp('2013-11-15 00:00:00'),
#  Timestamp('2013-12-16 00:00:00'),
#  Timestamp('2014-01-07 00:00:00'),
#  Timestamp('2014-01-08 00:00:00'),
#  Timestamp('2014-01-15 00:00:00'),
# ...
